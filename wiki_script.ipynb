# %%
from bs4 import BeautifulSoup as bs4
from telegram.ext import CommandHandler, Updater
import requests

# %%
def scrape(url):
    page  = requests.get(url)
    page_text = bs4(page.text,'html.parser')
    articles_text = page_text.find_all(class_ = "ZINbbc xpd O9g5cc uUPGi")
    return articles_text

# %%
def get_wiki_url(i):
    i = i.find('a').attrs['href'].replace('/url?q=','')
    return i

# %%
def get_wiki_page(update, context):
    chat_id = update.message.chat_id
    search_text=""
    for i in context.args:
        search_text = search_text + " " +i
    search_text = search_text + "+wiki"
    google_url = "https://www.google.com/search?q="+search_text+"&rlz=1C5CHFA_enIN908IN908&oq="+search_text+"&aqs=chrome.0.69i59.6224j0j1&sourceid=chrome&ie=UTF-8"
    google_page = requests.get(google_url)
    google_page = bs4(google_page.text,'html.parser')
    google_page = google_page.find(class_ = "ZINbbc xpd O9g5cc uUPGi")
    google_page = google_page.find('a')['href'].replace('/url?q=','')
    google_page = google_page.split("&sa")[0]
    
    update.message.reply_text(get_keyword_article(search_text))

# %%
def main():
    #day = datetime.datetime.now().strftime("%A")
    #time = int(datetime.datetime.now().strftime("%H"))
    
    updater = Updater('1183471904:AAENQORzTAU_mTDXfv8xJU1s3rmK1PuzlpU', use_context=True)
    dp = updater.dispatcher
    dp.add_handler(CommandHandler('wiki',get_wiki_info))
    #dp.add_handler(MessageHandler(~Filters.command & Filters.text, test))
    updater.start_polling()
    updater.idle()

if __name__ == '__main__':
    main()

# %%
url = "https://www.google.com/search?q=+james+webb+telescope+wiki&rlz=1C5CHFA_enIN908IN908&oq=+james+webb+telescope+wiki&aqs=chrome.0.69i59.6224j0j1&sourceid=chrome&ie=UTF-8"

page = requests.get(url)
page_text = bs4(page.text, 'html.parser')
wiki_div = page_text.find(class_ = "ZINbbc xpd O9g5cc uUPGi")
wiki_div
# Out:
# <div class="ZINbbc xpd O9g5cc uUPGi"><div class="kCrYT"><a href="/url?q=https://en.wikipedia.org/wiki/James_Webb_Space_Telescope&amp;sa=U&amp;ved=2ahUKEwjpxPnS4P_qAhVQb30KHSMVBY0QFjAAegQICRAB&amp;usg=AOvVaw0NPVe9ZIpMaCWPX1JuCpLA"><h3 class="zBAuLc"><div class="BNeawe vvjwJb AP7Wnd">James Webb Space Telescope - Wikipedia</div></h3><div class="BNeawe UPmit AP7Wnd">https://en.wikipedia.org › wiki › James_Webb_Space_Telescope</div></a></div><div class="x54gtf"></div><div class="kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd"><div><div><div class="Ap5OSd"><div class="BNeawe s3v9rd AP7Wnd">The James Webb Space Telescope (JWST or "Webb") is a space telescope that is planned to succeed the Hubble Space Telescope as NASA's flagship ...
#
# ...

# %%
wiki_div.find('a')['href']
# Out:
# '/url?q=https://en.wikipedia.org/wiki/James_Webb_Space_Telescope&sa=U&ved=2ahUKEwjIq_DW2v_qAhUBWX0KHammAVAQFjAAegQIChAB&usg=AOvVaw2VfB48F_AeK1lqZlXlFX2b'

# %%
print(page_text.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-IN">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    james webb telescope wiki - Google Search
#   </title>
#   <script nonce="79O8YRZ4y1u/uxGSgiqXww==">
#    (function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
search_text="+bortle+scale+wiki"
print(search_text,"\n--\n")
google_url = "https://www.google.com/search?q="+search_text+"&rlz=1C5CHFA_enIN908IN908&oq="+search_text+"&aqs=chrome.0.69i59.6224j0j1&sourceid=chrome&ie=UTF-8"
print(google_url,"\n--\n")
google_page = requests.get(google_url)
#print(google_page,"\n--\n")
google_page = bs4(google_page.text,'html.parser')
#print(google_page,"\n--\n")
google_page = google_page.find(class_ = "ZINbbc xpd O9g5cc uUPGi")
print(google_page,"\n--\n")
google_page = google_page.find('a')['href'].replace('/url?q=','')
print(google_page,"\n--\n")
google_page = google_page.split("&sa")[0]
print(google_page,"\n--\n")
# Out:
# +bortle+scale+wiki
# --
#
# https://www.google.com/search?q=+bortle+scale+wiki&rlz=1C5CHFA_enIN908IN908&oq=+bortle+scale+wiki&aqs=chrome.0.69i59.6224j0j1&sourceid=chrome&ie=UTF-8
# --
#
# <div class="ZINbbc xpd O9g5cc uUPGi"><div class="kCrYT"><a href="/url?q=https://en.wikipedia.org/wiki/Bortle_scale&amp;sa=U&amp;ved=2ahUKEwjzh8Psr4HrAhXg6nMBHVXMB10QFjAAegQIBBAB&amp;usg=AOvVaw2w0ZRQGJzdICdnZ1Gz7E3F"><h3 class="zBAuLc"><div class="BNeawe vvjwJb AP7Wnd">Bortle scale - Wikipedia</div></h3><div class="BNeawe UPmit AP7Wnd">https://en.wikipedia.org › wiki › Bortle_scale</div></a></div><div class="x54gtf"></div><div class="kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd"><div><div><div class="BNeawe s3v9rd AP7Wnd">The Bortle scale is a nine-level numeric scale that measures the night sky's brightness of a particular location. It quantifies the astronomical observability of ...
# ...

# %%
search_text="+andromeda+galaxy+wiki"
#search_text
google_url = "https://www.google.com/search?q="+search_text+"&rlz=1C5CHFA_enIN908IN908&oq="+search_text+"&aqs=chrome.0.69i59.6224j0j1&sourceid=chrome&ie=UTF-8"
google_url
google_page = requests.get(google_url)
#print(google_page)
google_page = bs4(google_page.text,'html.parser')
#print(google_page)
google_page = google_page.find(class_ = "ZINbbc xpd O9g5cc uUPGi")
#print(google_page)
google_page = google_page.find('a')['href'].replace('/url?q=','')
#print(google_page)
google_page = google_page.split("&sa")[0]
#google_page

# %%
wiki_link = "https://en.wikipedia.org/wiki/bortle_scale"
wiki_page = requests.get(wiki_link)
wiki_page = bs4(wiki_page.text,'html.parser')
print(wiki_page.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Bortle scale - Wikipedia
#   </title>
#   <script>
# ...

# %%
summary = wiki_page.find_all('p')
for i in summary:
    if(len(i.get_text()) > 30):
        print(len(i.get_text()))
        summary = i.get_text()
        break
summary #andromeda
# Out:
# 898
# "The Bortle scale is a nine-level numeric scale that measures the night sky's brightness of a particular location. It quantifies the astronomical observability of celestial objects and the interference caused by light pollution. John E. Bortle created the scale and published it in the February 2001 edition of Sky & Telescope magazine to help amateur astronomers evaluate the darkness of an observing site, and secondarily, to compare the darkness of observing sites. The scale ranges from Class 1, the darkest skies available on Earth, through Class 9, inner-city skies. It gives several criteria for each level beyond naked-eye limiting magnitude (NELM).[1] The accuracy and utility of the scale have been questioned in recent research.[2] The table below summarizes Bortle's descriptions of the classes. Some classes can have very drastic differences from the one next to it, e.g, Bortle 4 - 5.\n"

# %%
wiki_page.find('table').find('a')['href']
# Out:
# '#cite_note-3'

# %%
image_url = https://en.wikipedia.org

# %%
def get_wiki_link(search_text):
    google_url = "https://www.google.com/search?q="+search_text+"&rlz=1C5CHFA_enIN908IN908&oq="+search_text+"&aqs=chrome.0.69i59.6224j0j1&sourceid=chrome&ie=UTF-8"
    google_page = requests.get(google_url)
    google_page = bs4(google_page.text,'html.parser')
    google_page = google_page.find(class_ = "ZINbbc xpd O9g5cc uUPGi")
    wiki_link = google_page.find('a')['href'].replace('/url?q=','')
    wiki_link = wiki_link.split("&sa")[0]
    return(wiki_link)

# %%
def scrape_wiki(search_text):
    wiki_link = get_wiki_link(search_text)
    wiki_page = requests.get(wiki_link)
    wiki_page = bs4(wiki_page.text,'html.parser')
    summary = wiki_page.find_all('p')[1].get_text()
    image_url = "https://en.wikipedia.org"+ wiki_page.find('table').find('a')['href']
    text = summary + "\n\n" + wiki_link
    return(text)

# %%
def get_wiki_info(update, context):
    chat_id = update.message.chat_id
    search_text=""
    for i in context.args:
        search_text = search_text + " " +i
    search_text = search_text + "+wiki"
    update.message.reply_text(scrape_wiki(search_text))

# %%
scrape_wiki("+bortle+scale+wiki")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-6ce799bacde8> in <module>
# ----> 1 scrape_wiki("+bortle+scale+wiki")
#
# <ipython-input-4-ffcbf2eba06d> in scrape_wiki(search_text)
#       3     wiki_page = requests.get(wiki_link)
#       4     wiki_page = bs4(wiki_page.text,'html.parser')
# ----> 5     summary = wiki_page.find_all('p')[1].get_text()
#       6     image_url = "https://en.wikipedia.org"+ wiki_page.find('table').find('a')['href']
#       7     text = summary + "\n\n" + wiki_link
#
# IndexError: list index out of range
